# %%
TRAIN_DATA = "../data/external/train.csv"
TEST_DATA = "../data/external/test.csv"

#Target column in the data. 
TARGET = "SalePrice"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#display all dataframe columns
pd.options.display.max_columns = None

# %%
train = pd.read_csv(TRAIN_DATA)
print(f"Train data shape: {train.shape}")
train.head()
# Out:
# Train data shape: (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#Id is not meaningful and can be dropped. 
train.drop('Id', axis=1, inplace=True)

# %% [markdown]
# ### Target Values

# %%
print(f"SalePrice Minimum: ${train['SalePrice'].min()}")
print(f"SalePrice Maximum: ${train['SalePrice'].max()}")
print(f"SalePrice Null Values: {train['SalePrice'].isnull().sum()}")
# Out:
# SalePrice Minimum: $34900
# SalePrice Maximum: $755000
# SalePrice Null Values: 0

# %%
plt.figure(figsize=(9,6))
plt.hist(train['SalePrice'], bins=50)
plt.xlabel('SalePrice')
plt.ylabel('Number')
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.hist(np.log(train['SalePrice']), bins=50)
plt.xlabel('Log(SalePrice)')
plt.ylabel('Number')
plt.show()

# %% [markdown]
# ### Numerical and Categorical Variables

# %%
tmp = train.dtypes
print(tmp.value_counts())
tmp.head()
# Out:
# object     43
# int64      34
# float64     3
# dtype: int64
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
# Street          object
# dtype: object

# %%
vars_cat = tmp[tmp == 'O'].index
vars_num = [col for col in tmp.index if col not in vars_cat and col!= "SalePrice"]
print(f"Categorical Variables: {len(vars_cat)}")
print(f"Numerical Variables: {len(vars_num)}")
# Out:
# Categorical Variables: 43
# Numerical Variables: 36

# %%
train[vars_cat].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
train[vars_num].head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# ### Categorical Variables

# %%
print("Null values among categorical variables:")
tmp = train[vars_cat].isnull().sum() 
tmp[tmp>0]
# Out:
# Null values among categorical variables:
# Alley           1369
# MasVnrType         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
vars_cat_with_more_na = ["Alley", "FireplaceQu", "PoolQC", "Fence", "MiscFeature"]
vars_cat_with_few_na = [var for var in vars_cat if var not in vars_cat_with_more_na]
print(f"May missing values: {len(vars_cat_with_more_na)}")
print(f"Few missing values: {len(vars_cat_with_few_na)}")
print(f"Total: {len(vars_cat)}")
# Out:
# May missing values: 5
# Few missing values: 38
# Total: 43

# %% [markdown]
# ### Numerical Variables

# %%
print("Null values among numerical variables:")
tmp = train[vars_num].isnull().sum() 
tmp[tmp>0]
# Out:
# Null values among numerical variables:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64
